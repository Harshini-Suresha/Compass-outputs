# %%
import pandas as pd

df = pd.read_csv('final_stats_with_metadata.csv')

print(df.columns)
# Out:
# Index(['Unnamed: 0', 'wilcox_stat', 'wilcox_pval', 'cohens_d', 'adjusted_pval',
#        'metadata_r_id', 'reaction_name', 'formula', 'associated_genes',
#        'subsystem', 'EC_number', 'confidence'],
#       dtype='object')

# %%
filtered_df = df[df['adjusted_pval'] < 0.05]
print(filtered_df[['subsystem', 'adjusted_pval']])
# Out:
#                      subsystem  adjusted_pval
# 0        Propanoate metabolism       0.000013
# 1        Propanoate metabolism       0.000013
# 2          Tyrosine metabolism       0.000013
# 5          Tyrosine metabolism       0.045046
# 6          Tyrosine metabolism       0.045046
# ...                        ...            ...
# 1895  Transport, mitochondrial       0.028726
# 1896  Transport, mitochondrial       0.000013
# 1897      Fatty acid oxidation       0.000013
# 1898      Fatty acid oxidation       0.000013
# 1899  Transport, extracellular       0.001173
#
# [1794 rows x 2 columns]

# %%
filtered_df.to_csv('filtered_pathways_padj_lt_0.05.csv', index=False)

# %%
import pandas as pd

filtered_df = pd.read_csv('filtered_pathways_padj_lt_0.05.csv')

metadata_df = pd.read_csv('reaction_metadata.csv')

pyruvate_metadata = metadata_df[metadata_df['subsystem'].str.lower() == 'pyruvate metabolism']

pyruvate_reactions = pyruvate_metadata['reaction_name'].unique()

filtered_pyruvate_df = filtered_df[filtered_df['reaction_name'].isin(pyruvate_reactions)]

print(filtered_pyruvate_df)

filtered_pyruvate_df.to_csv('filtered_pyruvate_pathways.csv', index=False)
# Out:
#        Unnamed: 0  wilcox_stat  wilcox_pval  cohens_d  adjusted_pval  \
# 48     ACOAHi_pos        196.0     0.000007  3.411101       0.000013
# 109      ALR2_pos        181.0     0.000150  2.418598       0.000216
# 110      ALR3_pos        181.0     0.000150  2.418598       0.000216
# 614     GLYOX_pos        186.0     0.000058  1.321292       0.000086
# 695   LALDO2x_pos        182.0     0.000125  1.187522       0.000180
# 696     LALDO_neg        150.0     0.017967  0.755341       0.020113
# 697     LALDO_pos        196.0     0.000007  1.430181       0.000013
# 700     LDH_L_neg        196.0     0.000007  2.038629       0.000013
# 701     LDH_L_pos        172.0     0.000732  2.325090       0.001000
# 706     LGTHL_pos        150.0     0.017967  0.755341       0.020113
# 744      ME1m_pos        196.0     0.000007  5.148457       0.000013
# 745       ME2_pos        196.0     0.000007  4.368847       0.000013
# 746      ME2m_pos        196.0     0.000007  5.293165       0.000013
# 753     MGSA2_pos        194.0     0.000011  3.408237       0.000019
# 754      MGSA_pos        194.0     0.000011  3.413700       0.000019
# 930       PCm_pos        196.0     0.000007  5.403520       0.000013
# 986     PPDOx_pos        182.0     0.000125  1.187522       0.000180
# 987     PPDOy_pos        195.0     0.000009  1.622831       0.000016
# 1393    r0055_neg        196.0     0.000007  1.297268       0.000013
# 1394    r0055_pos        193.0     0.000014  2.861268       0.000023
# 1396    r0062_pos        187.0     0.000048  2.371992       0.000071
# 1784    r1459_neg        196.0     0.000007  4.500938       0.000013
# 1785    r1459_pos        196.0     0.000007  3.786659       0.000013
#
#      metadata_r_id                                      reaction_name  \
# 48          ACOAHi                               acetyl-CoA hydrolase
# 109           ALR2                   aldose reductase (methylglyoxal)
# 110           ALR3                          aldose reductase (acetol)
# 614          GLYOX                   hydroxyacylglutathione hydrolase
# 695        LALDO2x               D-Lactaldehyde:NAD+ 1-oxidoreductase
# 696          LALDO  D-Lactaldehyde:NAD+ oxidoreductase (glutathion...
# 697          LALDO  D-Lactaldehyde:NAD+ oxidoreductase (glutathion...
# 700          LDH_L                            L-lactate dehydrogenase
# 701          LDH_L                            L-lactate dehydrogenase
# 706          LGTHL                           lactoylglutathione lyase
# 744           ME1m                  malic enzyme (NAD), mitochondrial
# 745            ME2                                malic enzyme (NADP)
# 746           ME2m                 malic enzyme (NADP), mitochondrial
# 753          MGSA2              methyglyoxylate synthase 2 (from g3p)
# 754           MGSA                             methylglyoxal synthase
# 930            PCm                               pyruvate carboxylase
# 986          PPDOx             Propane-1,2-diol:NAD+ 1-oxidoreductase
# 987          PPDOy            Propane-1,2-diol:NADP+ 1-oxidoreductase
# 1393         r0055  2-Oxopropanal:NADP+ oxidoreductase Pyruvate me...
# 1394         r0055  2-Oxopropanal:NADP+ oxidoreductase Pyruvate me...
# 1396         r0062  Acetyl-CoA hydrolase Pyruvate metabolism EC:3....
# 1784         r1459                                 Transport reaction
# 1785         r1459                                 Transport reaction
#
#                                                 formula  \
# 48    1.00 * Water [c] + 1.00 * Acetyl-CoA [c] --> 1...
# 109   1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# 110   1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# 614   1.00 * Water [c] + 1.00 * (R)-S-lactoylglutath...
# 695   1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# 696   1.00 * Nicotinamide adenine dinucleotide [c] +...
# 697   1.00 * Nicotinamide adenine dinucleotide [c] +...
# 700   1.00 * Nicotinamide adenine dinucleotide [c] +...
# 701   1.00 * Nicotinamide adenine dinucleotide [c] +...
# 706   1.00 * methylglyoxal [c] + 1.00 * Reduced glut...
# 744   1.00 * Nicotinamide adenine dinucleotide [m] +...
# 745   1.00 * Nicotinamide adenine dinucleotide phosp...
# 746   1.00 * Nicotinamide adenine dinucleotide phosp...
# 753   1.00 * Glyceraldehyde 3-phosphate [c] --> 1.00...
# 754   1.00 * Dihydroxyacetone phosphate [c] --> 1.00...
# 930   1.00 * pyruvate [m] + 1.00 * ATP [m] + 1.00 * ...
# 986   1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# 987   1.00 * proton [c] + 1.00 * Nicotinamide adenin...
# 1393  1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# 1394  1.00 * Water [c] + 1.00 * Nicotinamide adenine...
# 1396  1.00 * Water [m] + 1.00 * Acetyl-CoA [m] --> 1...
# 1784  1.00 * Diphosphate [c] --> 1.00 * Diphosphate ...
# 1785  1.00 * Diphosphate [c] --> 1.00 * Diphosphate ...
#
#                       associated_genes                   subsystem EC_number  \
# 48                              ACOT12         Pyruvate metabolism   3.1.2.1
# 109             AKR1A1; AKR1B3; AKR7A5         Pyruvate metabolism  1.1.1.21
# 110             AKR1A1; AKR1B3; AKR7A5         Pyruvate metabolism  1.1.1.21
# 614                        HAGH; HAGHL         Pyruvate metabolism   3.1.2.6
# 695                             AKR7A5         Pyruvate metabolism  1.1.1.21
# 696                               ADH5         Pyruvate metabolism   1.1.1.1
# 697                               ADH5         Pyruvate metabolism   1.1.1.1
# 700   LDHA; LDHAL6B; LDHB; LDHC; UEVLD  Glycolysis/gluconeogenesis  1.1.1.27
# 701   LDHA; LDHAL6B; LDHB; LDHC; UEVLD  Glycolysis/gluconeogenesis  1.1.1.27
# 706                               GLO1         Pyruvate metabolism   4.4.1.5
# 744                                ME2         Pyruvate metabolism  1.1.1.40
# 745                                ME1         Pyruvate metabolism  1.1.1.40
# 746                           ME2; ME3         Pyruvate metabolism  1.1.1.40
# 753                                NaN         Pyruvate metabolism   4.2.3.3
# 754                                NaN         Pyruvate metabolism   4.2.3.3
# 930                                PCX         Pyruvate metabolism   6.4.1.1
# 986                             AKR7A5         Pyruvate metabolism  1.1.1.21
# 987             AKR1A1; AKR1B3; AKR7A5         Pyruvate metabolism  1.1.1.21
# 1393                               NaN         Pyruvate metabolism  1.2.1.49
# 1394                               NaN         Pyruvate metabolism  1.2.1.49
# 1396                            ACOT12         Pyruvate metabolism   3.1.2.1
# 1784                               NaN          Transport, nuclear  1.3.1.27
# 1785                               NaN          Transport, nuclear  1.3.1.27
#
#       confidence
# 48           0.0
# 109          4.0
# 110          4.0
# 614          4.0
# 695          4.0
# 696          0.0
# 697          0.0
# 700          0.0
# 701          0.0
# 706          4.0
# 744          0.0
# 745          0.0
# 746          0.0
# 753          4.0
# 754          4.0
# 930          4.0
# 986          4.0
# 987          4.0
# 1393         0.0
# 1394         0.0
# 1396         0.0
# 1784         0.0
# 1785         0.0

# %%
positive_df = filtered_pyruvate_df[filtered_pyruvate_df['reaction_name'].str.endswith('_pos')]

negative_df = filtered_pyruvate_df[filtered_pyruvate_df['reaction_name'].str.endswith('_neg')]
positive_df.to_csv('filtered_pyruvate_pos.csv', index=False)
negative_df.to_csv('filtered_pyruvate_neg.csv', index=False)

# %%
import pandas as pd

meta_df = pd.read_csv('reaction_metadata.csv')

print(meta_df.columns)
# Out:
# Index(['reaction_no_direction', 'reaction_name', 'formula', 'associated_genes',
#        'subsystem', 'EC_number', 'confidence'],
#       dtype='object')

# %%
pyruvate_df = meta_df[meta_df['subsystem'].str.contains('Pyruvate Metabolism', case=False, na=False)]

print(pyruvate_df[['reaction_no_direction', 'reaction_name', 'subsystem']])
# Out:
#      reaction_no_direction                                      reaction_name  \
# 234                 ACOAHi                               acetyl-CoA hydrolase
# 252                 ACTLMO                               acetol monooxygenase
# 253                 ACTNMO                              acetone monooxygenase
# 361               ALCD21_D          alcohol dehydrogenase (D-1,2-propanediol)
# 362               ALCD21_L          alcohol dehydrogenase (L-1,2-propanediol)
# 363               ALCD22_D             alcohol dehydrogenase (D-lactaldehyde)
# 364               ALCD22_L             alcohol dehydrogenase (L-lactaldehyde)
# 381                   ALR2                   aldose reductase (methylglyoxal)
# 382                   ALR3                          aldose reductase (acetol)
# 2108                 GLYOX                   hydroxyacylglutathione hydrolase
# 2109                GLYOXm    hydroxyacylglutathione hydrolase, mitochondrial
# 2368                 LALDO  D-Lactaldehyde:NAD+ oxidoreductase (glutathion...
# 2369               LALDO2x               D-Lactaldehyde:NAD+ 1-oxidoreductase
# 2371                 LCADi                         lactaldehyde dehydrogenase
# 2372               LCADi_D                         lactaldehyde dehydrogenase
# 2373              LCADi_Dm          lactaldehyde dehydrogenase, mitochondrial
# 2374                LCADim          lactaldehyde dehydrogenase, mitochondrial
# 2381                 LDH_D                            D-lactate dehydrogenase
# 2383                LDH_Lm                            L-lactate dehydrogenase
# 2404                 LGTHL                           lactoylglutathione lyase
# 2411              L_LACDcm   L-Lactate dehydrogenase, cytosolic/mitochondrial
# 2516                  ME1m                  malic enzyme (NAD), mitochondrial
# 2517                   ME2                                malic enzyme (NADP)
# 2518                  ME2m                 malic enzyme (NADP), mitochondrial
# 2540                  MGSA                             methylglyoxal synthase
# 2541                 MGSA2              methyglyoxylate synthase 2 (from g3p)
# 2923                   PCm                               pyruvate carboxylase
# 3063                 PPDOx             Propane-1,2-diol:NAD+ 1-oxidoreductase
# 3064                 PPDOy            Propane-1,2-diol:NADP+ 1-oxidoreductase
# 3787                 r0055  2-Oxopropanal:NADP+ oxidoreductase Pyruvate me...
# 3789                 r0062  Acetyl-CoA hydrolase Pyruvate metabolism EC:3....
# 4133                 r0818                                 Transport reaction
#
#                 subsystem
# 234   Pyruvate metabolism
# 252   Pyruvate metabolism
# 253   Pyruvate metabolism
# 361   Pyruvate metabolism
# 362   Pyruvate metabolism
# 363   Pyruvate metabolism
# 364   Pyruvate metabolism
# 381   Pyruvate metabolism
# 382   Pyruvate metabolism
# 2108  Pyruvate metabolism
# 2109  Pyruvate metabolism
# 2368  Pyruvate metabolism
# 2369  Pyruvate metabolism
# 2371  Pyruvate metabolism
# 2372  Pyruvate metabolism
# 2373  Pyruvate metabolism
# 2374  Pyruvate metabolism
# 2381  Pyruvate metabolism
# 2383  Pyruvate metabolism
# 2404  Pyruvate metabolism
# 2411  Pyruvate metabolism
# 2516  Pyruvate metabolism
# 2517  Pyruvate metabolism
# 2518  Pyruvate metabolism
# 2540  Pyruvate metabolism
# 2541  Pyruvate metabolism
# 2923  Pyruvate metabolism
# 3063  Pyruvate metabolism
# 3064  Pyruvate metabolism
# 3787  Pyruvate metabolism
# 3789  Pyruvate metabolism
# 4133  Pyruvate metabolism

# %%
import pandas as pd

filtered_df = pd.read_csv('final_stats_with_metadata.csv')
metadata_df = pd.read_csv('reaction_metadata.csv')

pyruvate_metadata = metadata_df[metadata_df['subsystem'].str.lower() == 'pyruvate metabolism']
pyruvate_reactions = pyruvate_metadata['reaction_name'].unique()

pyruvate_not_significant = filtered_df[
    (filtered_df['reaction_name'].isin(pyruvate_reactions)) &
    (filtered_df['adjusted_pval'] >= 0.05)
]

pyruvate_not_significant.to_csv('pyruvate_metabolism_padj_gte_0.05.csv', index=False)

# %%
import pandas as pd

df = pd.read_csv('filtered_pathways_padj_lt_0.05.csv')

unique_subsystems = df['subsystem'].dropna().unique()

print("Unique subsystems with padj < 0.05:")
for subsystem in unique_subsystems:
    print(subsystem)
# Out:
# Unique subsystems with padj < 0.05:
# Propanoate metabolism
# Tyrosine metabolism
# Sphingolipid metabolism
# Tryptophan metabolism
# Taurine and hypotaurine metabolism
# Cytochrome metabolism
# Steroid metabolism
# Glycine, serine, alanine and threonine metabolism
# Lysine metabolism
# Glutamate metabolism
# beta-Alanine metabolism
# Valine, leucine, and isoleucine metabolism
# Cholesterol metabolism
# Fatty acid oxidation
# Aminosugar metabolism
# Phosphatidylinositol phosphate metabolism
# Glycerophospholipid metabolism
# Other
# Butanoate metabolism
# Pyruvate metabolism
# Bile acid synthesis
# Glycolysis/gluconeogenesis
# Purine catabolism
# Nucleotide interconversion
# Arginine and Proline Metabolism
# Nucleotide salvage pathway
# Purine synthesis
# Keratan sulfate synthesis
# Triacylglycerol synthesis
# Alanine and aspartate metabolism
# Methionine and cysteine metabolism
# N-glycan degradation
# Citric acid cycle
# Miscellaneous
# Eicosanoid metabolism
# Glutathione metabolism
# Starch and sucrose metabolism
# Pentose phosphate pathway
# Urea cycle
# Pyrimidine synthesis
# Oxidative phosphorylation
# Transport, lysosomal
# Biotin metabolism
# Vitamin A metabolism
# N-glycan synthesis
# Heme degradation
# Pyrimidine catabolism
# Transport, extracellular
# ROS detoxification
# O-glycan synthesis
# D-alanine metabolism
# Fatty acid synthesis
# Ubiquinone synthesis
# Tetrahydrobiopterin metabolism
# Keratan sulfate degradation
# Fructose and mannose metabolism
# Glyoxylate and dicarboxylate metabolism
# Galactose metabolism
# Folate metabolism
# Blood group synthesis
# Heparan sulfate degradation
# Chondroitin sulfate degradation
# Hyaluronan metabolism
# Histidine metabolism
# Inositol phosphate metabolism
# NAD metabolism
# Limonene and pinene degradation
# Transport, mitochondrial
# Vitamin B6 metabolism
# Phenylalanine metabolism
# Heme synthesis
# CoA synthesis
# Glycosphingolipid metabolism
# Androgen and estrogen synthesis and metabolism
# Vitamin B2 metabolism
# Thiamine metabolism
# Cysteine Metabolism
# Unassigned
# CoA catabolism
# Transport, peroxisomal
# Transport, nuclear

# %%
import pandas as pd

df = pd.read_csv('filtered_pathways_padj_lt_0.05.csv')

unique_subsystems = df['subsystem'].dropna().unique()

subsystem_df = pd.DataFrame(unique_subsystems, columns=['subsystem'])

subsystem_df.to_csv('Unique subsystems with padj lt 0.05.csv', index=False)

# %%
import pandas as pd

metadata_df = pd.read_csv('reaction_metadata.csv')

unique_subsystems = metadata_df['subsystem'].dropna().unique()

print("Unique Subsystems in reaction_metadata.csv:")
for subsystem in unique_subsystems:
    print(subsystem)

subsystem_df = pd.DataFrame(unique_subsystems, columns=['subsystem'])
subsystem_df.to_csv('unique_subsystems_from_reaction_metadata.csv', index=False)
# Out:
# Unique Subsystems in reaction_metadata.csv:
# Transport, lysosomal
# Transport, mitochondrial
# Transport, endoplasmic reticular
# beta-Alanine metabolism
# Vitamin D metabolism
# Transport, extracellular
# Lysine metabolism
# Glycine, serine, alanine and threonine metabolism
# Methionine and cysteine metabolism
# Pyrimidine catabolism
# Propanoate metabolism
# Tryptophan metabolism
# Tyrosine metabolism
# Ubiquinone synthesis
# Transport, nuclear
# Valine, leucine, and isoleucine metabolism
# Sphingolipid metabolism
# Butanoate metabolism
# Purine catabolism
# Taurine and hypotaurine metabolism
# Arginine and Proline Metabolism
# Cytochrome metabolism
# Steroid metabolism
# Heme synthesis
# N-glycan degradation
# O-glycan synthesis
# Blood group synthesis
# Glutamate metabolism
# Pentose phosphate pathway
# Cholesterol metabolism
# Fatty acid oxidation
# Transport, peroxisomal
# Transport, golgi apparatus
# Aminosugar metabolism
# Phosphatidylinositol phosphate metabolism
# Urea cycle
# Glycerophospholipid metabolism
# Citric acid cycle
# Pyruvate metabolism
# Bile acid synthesis
# Vitamin B2 metabolism
# Glycolysis/gluconeogenesis
# Nucleotide interconversion
# Nucleotide salvage pathway
# Selenoamino acid metabolism
# Purine synthesis
# Keratan sulfate synthesis
# Triacylglycerol synthesis
# Alanine and aspartate metabolism
# Miscellaneous
# Eicosanoid metabolism
# Glutathione metabolism
# Starch and sucrose metabolism
# Biotin metabolism
# R group synthesis
# Unassigned
# Vitamin C metabolism
# Pyrimidine synthesis
# Oxidative phosphorylation
# Vitamin A metabolism
# Stilbene, coumarine and lignin synthesis
# N-glycan synthesis
# Heme degradation
# Limonene and pinene degradation
# ROS detoxification
# Vitamin B12 metabolism
# C5-branched dibasic acid metabolism
# Alkaloid synthesis
# Chondroitin sulfate degradation
# D-alanine metabolism
# Fatty acid synthesis
# Folate metabolism
# Tetrahydrobiopterin metabolism
# Exchange/demand reaction
# CoA synthesis
# Keratan sulfate degradation
# Fructose and mannose metabolism
# Glyoxylate and dicarboxylate metabolism
# Galactose metabolism
# Nucleotide sugar metabolism
# Chondroitin synthesis
# Heparan sulfate degradation
# Hyaluronan metabolism
# Histidine metabolism
# Vitamin B6 metabolism
# Inositol phosphate metabolism
# CoA catabolism
# NAD metabolism
# Phenylalanine metabolism
# Thiamine metabolism
# Cysteine Metabolism
# Androgen and estrogen synthesis and metabolism
# Lipoate metabolism
# Arachidonic acid metabolism
# Vitamin E metabolism
# Linoleate metabolism
# Glycosphingolipid metabolism
# Xenobiotics metabolism
# Dietary fiber binding
# Squalene and cholesterol synthesis

# %%
import pandas as pd

df = pd.read_csv('final_stats_with_metadata.csv')

num_pathways = df['reaction_name'].nunique()
num_subsystems = df['subsystem'].nunique()

print(f" Number of unique pathways (reaction_name): {num_pathways}")
print(f" Number of unique subsystems: {num_subsystems}")

counts_df = pd.DataFrame({
    'category': ['unique_pathways', 'unique_subsystems'],
    'count': [num_pathways, num_subsystems]
})

counts_df.to_csv('final_stats_counts subsytem count.csv', index=False)
# Out:
#  Number of unique pathways (reaction_name): 1101
#  Number of unique subsystems: 83

# %%
import pandas as pd
df = pd.read_csv('final_stats_with_metadata.csv')

unique_pathways = df['reaction_name'].dropna().unique()
num_pathways = len(unique_pathways)

unique_subsystems = df['subsystem'].dropna().unique()
num_subsystems = len(unique_subsystems)

pathway_df = pd.DataFrame({'reaction_name': unique_pathways})
subsystem_df = pd.DataFrame({'subsystem': unique_subsystems})

pathway_count_df = pd.DataFrame({'reaction_name': [f'Total pathways: {num_pathways}']})
subsystem_count_df = pd.DataFrame({'subsystem': [f'Total subsystems: {num_subsystems}']})

final_pathway_df = pd.concat([pathway_count_df, pathway_df], ignore_index=True)
final_subsystem_df = pd.concat([subsystem_count_df, subsystem_df], ignore_index=True)

with pd.ExcelWriter('final_stats_pathways_and_subsystems.xlsx') as writer:
    final_pathway_df.to_excel(writer, sheet_name='Pathways', index=False)
    final_subsystem_df.to_excel(writer, sheet_name='Subsystems', index=False)

# %%
import pandas as pd
df = pd.read_csv("final_stats_with_metadata.csv")
df["polarity"] = df["Unnamed: 0"].apply(lambda x: "Pos" if "_pos" in x else ("Neg" if "_neg" in x else None))


df["significance"] = df["adjusted_pval"].apply(lambda x: "p<0.05" if x < 0.05 else "p≥0.05")

df["direction"] = df["cohens_d"].apply(lambda d: "d<0" if d < 0 else ("d>0" if d > 0 else None))

df = df.dropna(subset=["polarity", "direction"])

df["group"] = df["significance"] + "_" + df["polarity"] + "_" + df["direction"]

summary = df.groupby(["subsystem", "group"]).size().unstack(fill_value=0)

final_cols = [
    "p<0.05_Pos_d<0", "p<0.05_Pos_d>0", "p<0.05_Neg_d<0", "p<0.05_Neg_d>0",
    "p≥0.05_Pos_d<0", "p≥0.05_Pos_d>0", "p≥0.05_Neg_d<0", "p≥0.05_Neg_d>0"
]
for col in final_cols:
    if col not in summary.columns:
        summary[col] = 0

summary = summary[final_cols]
summary = summary.reset_index()

summary.to_csv("subsystem_detailed_significance_counts.csv", index=False)

print(summary.head())
# Out:
# group                                       subsystem  p<0.05_Pos_d<0  \
# 0                    Alanine and aspartate metabolism               0
# 1                               Aminosugar metabolism               0
# 2      Androgen and estrogen synthesis and metabolism               0
# 3                         Arachidonic acid metabolism               0
# 4                     Arginine and Proline Metabolism               0
#
# group  p<0.05_Pos_d>0  p<0.05_Neg_d<0  p<0.05_Neg_d>0  p≥0.05_Pos_d<0  \
# 0                  10               0               2               0
# 1                  15               0               1               1
# 2                   1               0               1               0
# 3                   0               0               0               0
# 4                  13               0               5               0
#
# group  p≥0.05_Pos_d>0  p≥0.05_Neg_d<0  p≥0.05_Neg_d>0
# 0                   0               0               0
# 1                   0               0               0
# 2                   0               0               0
# 3                   1               0               1
# 4                   0               0               0

# %%
import pandas as pd

df = pd.read_csv("final_stats_with_metadata.csv")  

df["direction"] = df["Unnamed: 0"].apply(lambda x: "Pos" if "_pos" in x else ("Neg" if "_neg" in x else None))

df = df.dropna(subset=["direction"])

df["category"] = df["adjusted_pval"].apply(lambda p: "p<0.05" if p < 0.05 else "p≥0.05")

df["group"] = df["category"] + "_" + df["direction"]

summary = df.groupby(["subsystem", "group"]).size().unstack(fill_value=0)

for col in ["p<0.05_Pos", "p<0.05_Neg", "p≥0.05_Pos", "p≥0.05_Neg"]:
    if col not in summary.columns:
        summary[col] = 0

summary = summary[["p<0.05_Pos", "p<0.05_Neg", "p≥0.05_Pos", "p≥0.05_Neg"]]

summary.reset_index(inplace=True)

summary.to_csv("subsystem_significance_summary_only_pval.csv", index=False)

print(summary.head())
# Out:
# group                                       subsystem  p<0.05_Pos  p<0.05_Neg  \
# 0                    Alanine and aspartate metabolism          10           2
# 1                               Aminosugar metabolism          15           1
# 2      Androgen and estrogen synthesis and metabolism           1           1
# 3                         Arachidonic acid metabolism           0           0
# 4                     Arginine and Proline Metabolism          13           5
#
# group  p≥0.05_Pos  p≥0.05_Neg
# 0               0           0
# 1               1           0
# 2               0           0
# 3               1           1
# 4               0           0

# %%
import pandas as pd

df = pd.read_csv('reaction_metadata.csv')

reaction_count = df.groupby('subsystem')['reaction_name'].count().reset_index()

reaction_count.columns = ['Subsystem', 'Number_of_Reactions']
reaction_count = reaction_count.sort_values(by='Number_of_Reactions', ascending=False)

reaction_count.to_csv('subsystem_reaction_counts.csv', index=False)

print(reaction_count.head())
# Out:
#                    Subsystem  Number_of_Reactions
# 78  Transport, extracellular                 1550
# 23      Fatty acid oxidation                  869
# 22  Exchange/demand reaction                  742
# 81  Transport, mitochondrial                  309
# 21     Eicosanoid metabolism                  257

# %%
import pandas as pd

reaction_df = pd.read_csv("reaction_metadata.csv")

reaction_df_unique = reaction_df.drop_duplicates(subset="reaction_name")

subsystem_counts = (
    reaction_df_unique.groupby("subsystem")["reaction_name"]
    .nunique()
    .reset_index()
    .rename(columns={"reaction_name": "Number_of_Unique_Reactions"})
    .sort_values(by="Number_of_Unique_Reactions", ascending=False)
)

subsystem_counts.to_csv("subsystem_unique_reaction_counts.csv", index=False)

print(subsystem_counts.head())
# Out:
#                      subsystem  Number_of_Unique_Reactions
# 22    Exchange/demand reaction                         714
# 78    Transport, extracellular                         598
# 23        Fatty acid oxidation                         571
# 81    Transport, mitochondrial                         204
# 52  Nucleotide interconversion                         166

# %%
import pandas as pd

file1 = pd.read_csv('subsystem_significance_summary_only_pval.csv')
file2 = pd.read_csv('subsystem_unique_reaction_counts.csv')

merged_df = file1.merge(file2, on='subsystem', how='left')

merged_df.to_csv('subsystem_significance_with_reaction_counts.csv', index=False)
print(merged_df.head())
# Out:
#                                         subsystem  p<0.05_Pos  p<0.05_Neg  \
# 0                Alanine and aspartate metabolism          10           2
# 1                           Aminosugar metabolism          15           1
# 2  Androgen and estrogen synthesis and metabolism           1           1
# 3                     Arachidonic acid metabolism           0           0
# 4                 Arginine and Proline Metabolism          13           5
#
#    p≥0.05_Pos  p≥0.05_Neg  Number_of_Unique_Reactions
# 0           0           0                        15.0
# 1           1           0                        27.0
# 2           0           0                        25.0
# 3           1           1                        29.0
# 4           0           0                        37.0

# %%
import pandas as pd

# Load your data
df = pd.read_csv("final_stats_with_metadata.csv")

# Function to extract top N rows with unique subsystems
def get_top_unique_subsystems(df, top_n):
    top_df = df.nsmallest(top_n, 'adjusted_pval')
    unique_df = top_df.drop_duplicates(subset='subsystem', keep='first')
    return unique_df[['subsystem', 'associated_genes']]

# Get each group separately
top10 = get_top_unique_subsystems(df, 10)
top25 = get_top_unique_subsystems(df, 25)
top50 = get_top_unique_subsystems(df, 50)
top75 = get_top_unique_subsystems(df, 75)

# Get top 10 frequent subsystems across the entire dataset
top_subsystems = df['subsystem'].value_counts().head(10).index.tolist()
top10_frequent = (
    df[df['subsystem'].isin(top_subsystems)]
    .drop_duplicates(subset='subsystem', keep='first')
    [['subsystem', 'associated_genes']]
)

# Print each section clearly
print("🔹 Top 10 Adjusted P-value Subsystems:\n", top10, "\n")
print("🔹 Top 25 Adjusted P-value Subsystems:\n", top25, "\n")
print("🔹 Top 50 Adjusted P-value Subsystems:\n", top50, "\n")
print("🔹 Top 75 Adjusted P-value Subsystems:\n", top75, "\n")
print("🔹 Top 10 Frequent Subsystems (based on occurrence):\n", top10_frequent, "\n")

# Optional: Save each as separate file
top10.to_csv("top10_subsystems.csv", index=False)
top25.to_csv("top25_subsystems.csv", index=False)
top50.to_csv("top50_subsystems.csv", index=False)
top75.to_csv("top75_subsystems.csv", index=False)
top10_frequent.to_csv("top10_frequent_subsystems.csv", index=False)
# Out:
# 🔹 Top 10 Adjusted P-value Subsystems:
#                    subsystem                       associated_genes
# 0     Propanoate metabolism       LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 2       Tyrosine metabolism  ADH1; ADH4; ADH5; ADH6A; ADH7; ADHFE1
# 8   Sphingolipid metabolism                                   KDSR
# 14    Cytochrome metabolism                                SULT1A1
# 15       Steroid metabolism                       SULT1A1; SULT2A1
#
# 🔹 Top 25 Adjusted P-value Subsystems:
#                                              subsystem  \
# 0                               Propanoate metabolism
# 2                                 Tyrosine metabolism
# 8                             Sphingolipid metabolism
# 14                              Cytochrome metabolism
# 15                                 Steroid metabolism
# 19  Glycine, serine, alanine and threonine metabolism
# 20                                  Lysine metabolism
# 22                               Glutamate metabolism
# 24                            beta-Alanine metabolism
# 25         Valine, leucine, and isoleucine metabolism
# 27                              Tryptophan metabolism
# 30                             Cholesterol metabolism
# 31                               Fatty acid oxidation
#
#                          associated_genes
# 0        LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 2   ADH1; ADH4; ADH5; ADH6A; ADH7; ADHFE1
# 8                                    KDSR
# 14                                SULT1A1
# 15                       SULT1A1; SULT2A1
# 19                                   AOC3
# 20                                  AADAT
# 22                                   ABAT
# 24                                ALDH9A1
# 25                    ACAA2; ACAT1; HADHB
# 27                                  ACAT3
# 30                                  ACAT3
# 31                                 ACAA1B
#
# 🔹 Top 50 Adjusted P-value Subsystems:
#                                              subsystem  \
# 0                               Propanoate metabolism
# 2                                 Tyrosine metabolism
# 8                             Sphingolipid metabolism
# 14                              Cytochrome metabolism
# 15                                 Steroid metabolism
# 19  Glycine, serine, alanine and threonine metabolism
# 20                                  Lysine metabolism
# 22                               Glutamate metabolism
# 24                            beta-Alanine metabolism
# 25         Valine, leucine, and isoleucine metabolism
# 27                              Tryptophan metabolism
# 30                             Cholesterol metabolism
# 31                               Fatty acid oxidation
# 37                              Aminosugar metabolism
# 41          Phosphatidylinositol phosphate metabolism
# 43                                              Other
# 47                               Butanoate metabolism
# 50                                Pyruvate metabolism
# 56                                Bile acid synthesis
# 58                         Glycolysis/gluconeogenesis
# 59                                  Purine catabolism
# 65                    Arginine and Proline Metabolism
# 66                         Nucleotide interconversion
#
#                                      associated_genes
# 0                    LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 2               ADH1; ADH4; ADH5; ADH6A; ADH7; ADHFE1
# 8                                                KDSR
# 14                                            SULT1A1
# 15                                   SULT1A1; SULT2A1
# 19                                               AOC3
# 20                                              AADAT
# 22                                               ABAT
# 24                                            ALDH9A1
# 25                                ACAA2; ACAT1; HADHB
# 27                                              ACAT3
# 30                                              ACAT3
# 31                                             ACAA1B
# 37                                              RENBP
# 41                                               PIGL
# 43                                               ACLY
# 47  ACAD11; ACAD12; ACAD8; ACAD9; ACADM; ACADS; AC...
# 50                                             ACOT12
# 56                                              ACOX2
# 58                                        AACS; ACSS2
# 59                                                ADA
# 65                                               AMD1
# 66  ADCY1; ADCY10; ADCY2; ADCY3; ADCY4; ADCY5; ADC...
#
# 🔹 Top 75 Adjusted P-value Subsystems:
#                                              subsystem  \
# 0                               Propanoate metabolism
# 2                                 Tyrosine metabolism
# 8                             Sphingolipid metabolism
# 14                              Cytochrome metabolism
# 15                                 Steroid metabolism
# 19  Glycine, serine, alanine and threonine metabolism
# 20                                  Lysine metabolism
# 22                               Glutamate metabolism
# 24                            beta-Alanine metabolism
# 25         Valine, leucine, and isoleucine metabolism
# 27                              Tryptophan metabolism
# 30                             Cholesterol metabolism
# 31                               Fatty acid oxidation
# 37                              Aminosugar metabolism
# 41          Phosphatidylinositol phosphate metabolism
# 43                                              Other
# 47                               Butanoate metabolism
# 50                                Pyruvate metabolism
# 56                                Bile acid synthesis
# 58                         Glycolysis/gluconeogenesis
# 59                                  Purine catabolism
# 65                    Arginine and Proline Metabolism
# 66                         Nucleotide interconversion
# 68                         Nucleotide salvage pathway
# 72                                   Purine synthesis
# 73                          Keratan sulfate synthesis
# 92                          Triacylglycerol synthesis
#
#                                      associated_genes
# 0                    LDHA; LDHAL6B; LDHB; LDHC; UEVLD
# 2               ADH1; ADH4; ADH5; ADH6A; ADH7; ADHFE1
# 8                                                KDSR
# 14                                            SULT1A1
# 15                                   SULT1A1; SULT2A1
# 19                                               AOC3
# 20                                              AADAT
# 22                                               ABAT
# 24                                            ALDH9A1
# 25                                ACAA2; ACAT1; HADHB
# 27                                              ACAT3
# 30                                              ACAT3
# 31                                             ACAA1B
# 37                                              RENBP
# 41                                               PIGL
# 43                                               ACLY
# 47  ACAD11; ACAD12; ACAD8; ACAD9; ACADM; ACADS; AC...
# 50                                             ACOT12
# 56                                              ACOX2
# 58                                        AACS; ACSS2
# 59                                                ADA
# 65                                               AMD1
# 66  ADCY1; ADCY10; ADCY2; ADCY3; ADCY4; ADCY5; ADC...
# 68                                               APRT
# 72                                               ADSL
# 73  B3GNT2; B3GNT3; B3GNT4; B3GNT7; B3GNT8; B3GNTL...
# 92  AGPAT1; AGPAT2; AGPAT3; AGPAT4; AGPAT5; GPAT4;...
#
# 🔹 Top 10 Frequent Subsystems (based on occurrence):
#                                         subsystem     associated_genes
# 8                        Sphingolipid metabolism                 KDSR
# 15                            Steroid metabolism     SULT1A1; SULT2A1
# 25    Valine, leucine, and isoleucine metabolism  ACAA2; ACAT1; HADHB
# 31                          Fatty acid oxidation               ACAA1B
# 42                Glycerophospholipid metabolism                 ACHE
# 56                           Bile acid synthesis                ACOX2
# 61                    Nucleotide interconversion             AK2; AK4
# 156                           N-glycan synthesis                 ALG1
# 345                  Keratan sulfate degradation                  NaN
# 1468                                  Unassigned         ACSS1; ACSS2
